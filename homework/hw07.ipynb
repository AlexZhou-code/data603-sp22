# %% [markdown]
# This FINAL homework recaps the Spark ML library:
#
# 0) Download the "Rain in Australia" dataset from Kaggle (it is also attached to this assigbnment): https://www.kaggle.com/jsphyg/weather-dataset-rattle-package
#
# 1) In a Jupyter Notebook, write a SparkML script that uses a Decision Tree Classifier to predict the RainTomorrow target varible
#
# 2) Split the data 80/20 train/test, using a seed of 12345
#
# 3) Use transformers to remove unnecessary columns (use your best judgement) and convert categorical variables into one-hot encoded variables
#
# 4) Use a parameter grid to determine the best parameters for: impurity - gini, entropy maxBins - 5, 10, 15 minInfoGain - 0.0, 0.2, 0.4 maxDepth - 3, 5, 7
#
# 5) Cross-validate with 4 folds
#
# 6) Use a pipeline to encapsulate all steps
#
# 7) Print the parameters from the best model selected
#
# 8) Calculate and print the Area under ROC Curve and Area under Precision-Recall Curve scores for your training and test data sets (these are built-in metrics, you do not need to calculate anything by hand)
#
# Your script should be clean of all the testing and exploration and should only contain the necessary code to satisfy the above conditions

# %% [markdown]
# ## library load

# %%
from pyspark.sql import SparkSession
from pyspark.ml import Pipeline
from pyspark.ml.classification import DecisionTreeClassifier
from pyspark.ml.feature import StringIndexer, VectorIndexer
from pyspark.ml.evaluation import MulticlassClassificationEvaluator
from pyspark.ml.feature import RFormula
from pyspark.ml.tuning import CrossValidator, ParamGridBuilder
from pyspark.mllib.evaluation import BinaryClassificationMetrics

# %% [markdown]
# ## create data frame

# %%
spark = SparkSession.builder.getOrCreate()
df=spark.read.option("header", "true").csv("weatherAUS.csv")
df.show(5)
# Out:
# +----------+--------+-------+-------+--------+-----------+--------+-----------+-------------+----------+----------+------------+------------+-----------+-----------+-----------+-----------+--------+--------+-------+-------+---------+------------+
# |      Date|Location|MinTemp|MaxTemp|Rainfall|Evaporation|Sunshine|WindGustDir|WindGustSpeed|WindDir9am|WindDir3pm|WindSpeed9am|WindSpeed3pm|Humidity9am|Humidity3pm|Pressure9am|Pressure3pm|Cloud9am|Cloud3pm|Temp9am|Temp3pm|RainToday|RainTomorrow|
# +----------+--------+-------+-------+--------+-----------+--------+-----------+-------------+----------+----------+------------+------------+-----------+-----------+-----------+-----------+--------+--------+-------+-------+---------+------------+
# |2008-12-01|  Albury|   13.4|   22.9|     0.6|         NA|      NA|          W|           44|         W|       WNW|          20|          24|         71|         22|     1007.7|     1007.1|       8|      NA|   16.9|   21.8|       No|          No|
# |2008-12-02|  Albury|    7.4|   25.1|       0|         NA|      NA|        WNW|           44|       NNW|       WSW|           4|          22|         44|         25|     1010.6|     1007.8|      NA|      NA|   17.2|   24.3|       No|          No|
# |2008-12-03|  Albury|   12.9|   25.7|       0|         NA|      NA|        WSW|           46|         W|       WSW|          19|          26|         38|         30|     1007.6|     1008.7|      NA|       2|     21|   23.2|       No|          No|
# |2008-12-04|  Albury|    9.2|     28|       0|         NA|      NA|         NE|           24|        SE|         E|          11|           9|         45|         16|     1017.6|     1012.8|      NA|      NA|   18.1|   26.5|       No|          No|
# |2008-12-05|  Albury|   17.5|   32.3|       1|         NA|      NA|          W|           41|       ENE|        NW|           7|          20|         82|         33|     1010.8|       1006|       7|       8|   17.8|   29.7|       No|          No|
# +----------+--------+-------+-------+--------+-----------+--------+-----------+-------------+----------+----------+------------+------------+-----------+-----------+-----------+-----------+--------+--------+-------+-------+---------+------------+
# only showing top 5 rows

# %% [markdown]
# ## I saw some NA block in the csv, so I drop them

# %%
col_list=df.toPandas().columns.values.tolist()
df.select ("RainTomorrow").distinct().collect()
df_clean=df.where(df["RainTomorrow"] != "NA")

# %% [markdown]
# ## using Rformula to read data
# http://zwmiller.com/projects/spark_ml_example_part2.html

# %%
formula = RFormula(formula="RainTomorrow ~ .",featuresCol="features",labelCol="label")
output = formula.fit(df_clean).transform(df_clean)

# %% [markdown]
# ### A label indexer that maps a string column of labels to an ML column of label indices. If the input column is numeric, we cast it to string and index the string values.
# ### Class for indexing categorical feature columns in a dataset of Vector.
# ### follow the requirement to split the data

# %%
labelIndexer = StringIndexer(inputCol="label", outputCol="indexedLabel").fit(output)
featureIndexer = (VectorIndexer(inputCol="features", outputCol="indexedFeatures", maxCategories=2).fit(output))
(trainingData, testData) = output.randomSplit([0.8, 0.2], seed=12345)
# Out:
# 22/04/27 23:44:30 WARN DAGScheduler: Broadcasting large task binary with size 1494.4 KiB

# %% [markdown]
# ### DecisionTreeClassifier created
# ### pipline created

# %%
dt = DecisionTreeClassifier(labelCol="indexedLabel", featuresCol="indexedFeatures")
pipeline = Pipeline(stages=[labelIndexer, featureIndexer, dt])

# %%
evaluator = MulticlassClassificationEvaluator(
    labelCol="indexedLabel", predictionCol="prediction", metricName="accuracy")

# %% [markdown]
# ### setting up the require vaule

# %%
grid = ParamGridBuilder().addGrid(dt.impurity, ["gini", "entropy"]).addGrid(dt.maxBins, [5, 10, 15]).addGrid(dt.minInfoGain, [0.0, 0.2, 0.4]).addGrid(dt.maxDepth, [3, 5, 7]).build()

# %%
cv= CrossValidator(estimator=pipeline, evaluator=evaluator, estimatorParamMaps=grid, numFolds=4)

# %% [markdown]
# ## training

# %%
cvModel = cv.fit(trainingData)
# Out:
# 22/04/27 10:58:32 WARN DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 22/04/27 10:58:35 WARN DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 22/04/27 10:58:38 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 22/04/27 10:58:44 WARN MemoryStore: Not enough space to cache rdd_275_3 in memory! (computed 67.5 MiB so far)
# 22/04/27 10:58:44 WARN BlockManager: Persisting block rdd_275_3 to disk instead.
# 22/04/27 10:58:44 WARN MemoryStore: Not enough space to cache rdd_275_0 in memory! (computed 103.7 MiB so far)
# 22/04/27 10:58:44 WARN BlockManager: Persisting block rdd_275_0 to disk instead.
# 22/04/27 10:58:44 WARN MemoryStore: Not enough space to cache rdd_275_1 in memory! (computed 103.7 MiB so far)
# 22/04/27 10:58:44 WARN BlockManager: Persisting block rdd_275_1 to disk instead.
# 22/04/27 10:58:45 WARN MemoryStore: Not enough space to cache rdd_275_2 in memory! (computed 355.0 MiB so far)
# 22/04/27 10:58:45 WARN BlockManager: Persisting block rdd_275_2 to disk instead.
# 22/04/27 10:58:45 WARN MemoryStore: Not enough space to cache rdd_275_3 in memory! (computed 44.0 MiB so far)
# 22/04/27 10:58:48 WARN MemoryStore: Not enough space to cache rdd_275_0 in memory! (computed 155.9 MiB so far)
# 22/04/27 10:58:48 WARN MemoryStore: Not enough space to cache rdd_275_2 in memory! (computed 103.7 MiB so far)
# 22/04/27 10:58:49 WARN MemoryStore: Not enough space to cache rdd_275_1 in memory! (computed 355.2 MiB so far)
# 22/04/27 10:58:50 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 22/04/27 10:58:51 WARN MemoryStore: Not enough space to cache rdd_275_3 in memory! (computed 103.7 MiB so far)
# 22/04/27 10:58:51 WARN MemoryStore: Not enough space to cache rdd_275_2 in memory! (computed 103.7 MiB so far)
# 22/04/27 10:58:51 WARN MemoryStore: Not enough space to cache rdd_275_0 in memory! (computed 103.7 MiB so far)
# 22/04/27 10:58:51 WARN MemoryStore: Not enough space to cache rdd_275_1 in memory! (computed 103.7 MiB so far)
# 22/04/27 10:58:53 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 22/04/27 10:58:53 WARN MemoryStore: Not enough space to cache rdd_275_1 in memory! (computed 103.7 MiB so far)
# 22/04/27 10:58:53 WARN MemoryStore: Not enough space to cache rdd_275_2 in memory! (computed 103.7 MiB so far)
# 22/04/27 10:58:53 WARN MemoryStore: Not enough space to cache rdd_275_0 in memory! (computed 103.7 MiB so far)
# 22/04/27 10:58:53 WARN MemoryStore: Not enough space to cache rdd_275_3 in memory! (computed 103.7 MiB so far)
# 22/04/27 10:58:55 WARN DAGScheduler: Broadcasting large task binary with size 2.4 MiB
# 22/04/27 10:58:58 WARN DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 22/04/27 10:58:58 WARN DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 22/04/27 10:58:59 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 22/04/27 10:59:00 WARN MemoryStore: Not enough space to cache rdd_321_3 in memory! (computed 67.5 MiB so far)
# 22/04/27 10:59:00 WARN BlockManager: Persisting block rdd_321_3 to disk instead.
# 22/04/27 10:59:00 WARN MemoryStore: Not enough space to cache rdd_321_1 in memory! (computed 103.7 MiB so far)
# 22/04/27 10:59:00 WARN BlockManager: Persisting block rdd_321_1 to disk instead.
# 22/04/27 10:59:00 WARN MemoryStore: Not enough space to cache rdd_321_0 in memory! (computed 103.7 MiB so far)
# 22/04/27 10:59:00 WARN BlockManager: Persisting block rdd_321_0 to disk instead.
# 22/04/27 10:59:01 WARN MemoryStore: Not enough space to cache rdd_321_2 in memory! (computed 355.0 MiB so far)
# 22/04/27 10:59:01 WARN BlockManager: Persisting block rdd_321_2 to disk instead.
# 22/04/27 10:59:01 WARN MemoryStore: Not enough space to cache rdd_321_3 in memory! (computed 44.0 MiB so far)
# 22/04/27 10:59:04 WARN MemoryStore: Not enough space to cache rdd_321_2 in memory! (computed 103.7 MiB so far)
# 22/04/27 10:59:04 WARN MemoryStore: Not enough space to cache rdd_321_0 in memory! (computed 155.9 MiB so far)
# 22/04/27 10:59:04 WARN MemoryStore: Not enough space to cache rdd_321_1 in memory! (computed 355.2 MiB so far)
# 22/04/27 10:59:06 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 22/04/27 10:59:06 WARN MemoryStore: Not enough space to cache rdd_321_0 in memory! (computed 103.7 MiB so far)
# 22/04/27 10:59:06 WARN MemoryStore: Not enough space to cache rdd_321_1 in memory! (computed 103.7 MiB so far)
# 22/04/27 10:59:06 WARN MemoryStore: Not enough space to cache rdd_321_3 in memory! (computed 103.7 MiB so far)
# 22/04/27 10:59:06 WARN MemoryStore: Not enough space to cache rdd_321_2 in memory! (computed 103.7 MiB so far)
# 22/04/27 10:59:08 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 22/04/27 10:59:08 WARN MemoryStore: Not enough space to cache rdd_321_2 in memory! (computed 103.7 MiB so far)
# 22/04/27 10:59:08 WARN MemoryStore: Not enough space to cache rdd_321_0 in memory! (computed 103.7 MiB so far)
# 22/04/27 10:59:08 WARN MemoryStore: Not enough space to cache rdd_321_1 in memory! (computed 103.7 MiB so far)
# 22/04/27 10:59:08 WARN MemoryStore: Not enough space to cache rdd_321_3 in memory! (computed 103.7 MiB so far)
# 22/04/27 10:59:10 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 22/04/27 10:59:10 WARN MemoryStore: Not enough space to cache rdd_321_2 in memory! (computed 103.7 MiB so far)
# 22/04/27 10:59:10 WARN MemoryStore: Not enough space to cache rdd_321_1 in memory! (computed 103.7 MiB so far)
# 22/04/27 10:59:10 WARN MemoryStore: Not enough space to cache rdd_321_3 in memory! (computed 103.7 MiB so far)
# 22/04/27 10:59:10 WARN MemoryStore: Not enough space to cache rdd_321_0 in memory! (computed 103.7 MiB so far)
# 22/04/27 10:59:12 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 22/04/27 10:59:12 WARN MemoryStore: Not enough space to cache rdd_321_1 in memory! (computed 103.7 MiB so far)
# 22/04/27 10:59:12 WARN MemoryStore: Not enough space to cache rdd_321_2 in memory! (computed 103.7 MiB so far)
# 22/04/27 10:59:12 WARN MemoryStore: Not enough space to cache rdd_321_3 in memory! (computed 103.7 MiB so far)
# 22/04/27 10:59:12 WARN MemoryStore: Not enough space to cache rdd_321_0 in memory! (computed 103.7 MiB so far)
# 22/04/27 10:59:15 WARN DAGScheduler: Broadcasting large task binary with size 2.4 MiB
# 22/04/27 10:59:15 WARN DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 22/04/27 10:59:15 WARN DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 22/04/27 10:59:16 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 22/04/27 10:59:16 WARN MemoryStore: Not enough space to cache rdd_368_3 in memory! (computed 67.5 MiB so far)
# 22/04/27 10:59:16 WARN BlockManager: Persisting block rdd_368_3 to disk instead.
# 22/04/27 10:59:17 WARN MemoryStore: Not enough space to cache rdd_368_2 in memory! (computed 103.7 MiB so far)
# 22/04/27 10:59:17 WARN BlockManager: Persisting block rdd_368_2 to disk instead.
# 22/04/27 10:59:17 WARN MemoryStore: Not enough space to cache rdd_368_0 in memory! (computed 103.7 MiB so far)
# 22/04/27 10:59:17 WARN BlockManager: Persisting block rdd_368_0 to disk instead.
# 22/04/27 10:59:17 WARN MemoryStore: Not enough space to cache rdd_368_1 in memory! (computed 355.0 MiB so far)
# 22/04/27 10:59:17 WARN BlockManager: Persisting block rdd_368_1 to disk instead.
# 22/04/27 10:59:18 WARN MemoryStore: Not enough space to cache rdd_368_3 in memory! (computed 44.0 MiB so far)
# 22/04/27 10:59:20 WARN MemoryStore: Not enough space to cache rdd_368_2 in memory! (computed 103.7 MiB so far)
# 22/04/27 10:59:20 WARN MemoryStore: Not enough space to cache rdd_368_1 in memory! (computed 155.9 MiB so far)
# 22/04/27 10:59:20 WARN MemoryStore: Not enough space to cache rdd_368_0 in memory! (computed 155.9 MiB so far)
# 22/04/27 10:59:22 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 22/04/27 10:59:22 WARN MemoryStore: Not enough space to cache rdd_368_1 in memory! (computed 103.7 MiB so far)
# 22/04/27 10:59:22 WARN MemoryStore: Not enough space to cache rdd_368_2 in memory! (computed 103.7 MiB so far)
# 22/04/27 10:59:22 WARN MemoryStore: Not enough space to cache rdd_368_0 in memory! (computed 103.7 MiB so far)
# 22/04/27 10:59:22 WARN MemoryStore: Not enough space to cache rdd_368_3 in memory! (computed 103.7 MiB so far)
# 22/04/27 10:59:24 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 22/04/27 10:59:24 WARN MemoryStore: Not enough space to cache rdd_368_2 in memory! (computed 103.7 MiB so far)
# 22/04/27 10:59:24 WARN MemoryStore: Not enough space to cache rdd_368_3 in memory! (computed 103.7 MiB so far)
# 22/04/27 10:59:24 WARN MemoryStore: Not enough space to cache rdd_368_1 in memory! (computed 103.7 MiB so far)
# 22/04/27 10:59:24 WARN MemoryStore: Not enough space to cache rdd_368_0 in memory! (computed 103.7 MiB so far)
# 22/04/27 10:59:26 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 22/04/27 10:59:26 WARN MemoryStore: Not enough space to cache rdd_368_0 in memory! (computed 103.7 MiB so far)
# 22/04/27 10:59:26 WARN MemoryStore: Not enough space to cache rdd_368_2 in memory! (computed 103.7 MiB so far)
# 22/04/27 10:59:26 WARN MemoryStore: Not enough space to cache rdd_368_3 in memory! (computed 103.7 MiB so far)
# 22/04/27 10:59:26 WARN MemoryStore: Not enough space to cache rdd_368_1 in memory! (computed 103.7 MiB so far)
# 22/04/27 10:59:28 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 22/04/27 10:59:28 WARN MemoryStore: Not enough space to cache rdd_368_3 in memory! (computed 103.7 MiB so far)
# 22/04/27 10:59:28 WARN MemoryStore: Not enough space to cache rdd_368_2 in memory! (computed 103.7 MiB so far)
# 22/04/27 10:59:28 WARN MemoryStore: Not enough space to cache rdd_368_1 in memory! (computed 103.7 MiB so far)
# 22/04/27 10:59:28 WARN MemoryStore: Not enough space to cache rdd_368_0 in memory! (computed 103.7 MiB so far)
# 22/04/27 10:59:30 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 22/04/27 10:59:31 WARN MemoryStore: Not enough space to cache rdd_368_1 in memory! (computed 103.7 MiB so far)
# 22/04/27 10:59:31 WARN MemoryStore: Not enough space to cache rdd_368_3 in memory! (computed 103.7 MiB so far)
# 22/04/27 10:59:31 WARN MemoryStore: Not enough space to cache rdd_368_0 in memory! (computed 103.7 MiB so far)
# 22/04/27 10:59:31 WARN MemoryStore: Not enough space to cache rdd_368_2 in memory! (computed 103.7 MiB so far)
# 22/04/27 10:59:33 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 22/04/27 10:59:33 WARN MemoryStore: Not enough space to cache rdd_368_1 in memory! (computed 103.7 MiB so far)
# 22/04/27 10:59:33 WARN MemoryStore: Not enough space to cache rdd_368_2 in memory! (computed 103.7 MiB so far)
# 22/04/27 10:59:33 WARN MemoryStore: Not enough space to cache rdd_368_0 in memory! (computed 103.7 MiB so far)
# 22/04/27 10:59:33 WARN MemoryStore: Not enough space to cache rdd_368_3 in memory! (computed 103.7 MiB so far)
# 22/04/27 10:59:36 WARN DAGScheduler: Broadcasting large task binary with size 2.4 MiB
# 22/04/27 10:59:37 WARN DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 22/04/27 10:59:37 WARN DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 22/04/27 10:59:37 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 22/04/27 10:59:38 WARN MemoryStore: Not enough space to cache rdd_421_2 in memory! (computed 67.5 MiB so far)
# 22/04/27 10:59:38 WARN BlockManager: Persisting block rdd_421_2 to disk instead.
# 22/04/27 10:59:38 WARN MemoryStore: Not enough space to cache rdd_421_1 in memory! (computed 103.7 MiB so far)
# 22/04/27 10:59:38 WARN MemoryStore: Not enough space to cache rdd_421_0 in memory! (computed 103.7 MiB so far)
# 22/04/27 10:59:38 WARN BlockManager: Persisting block rdd_421_1 to disk instead.
# 22/04/27 10:59:38 WARN BlockManager: Persisting block rdd_421_0 to disk instead.
# 22/04/27 10:59:41 WARN MemoryStore: Not enough space to cache rdd_421_1 in memory! (computed 29.2 MiB so far)
# 22/04/27 10:59:41 WARN MemoryStore: Not enough space to cache rdd_421_2 in memory! (computed 44.0 MiB so far)
# 22/04/27 10:59:41 WARN MemoryStore: Not enough space to cache rdd_421_0 in memory! (computed 67.5 MiB so far)
# 22/04/27 10:59:43 WARN DAGScheduler: Broadcasting large task binary with size 2.4 MiB
# 22/04/27 10:59:44 WARN DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 22/04/27 10:59:44 WARN DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 22/04/27 10:59:45 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 22/04/27 10:59:45 WARN MemoryStore: Not enough space to cache rdd_456_2 in memory! (computed 67.5 MiB so far)
# 22/04/27 10:59:45 WARN BlockManager: Persisting block rdd_456_2 to disk instead.
# 22/04/27 10:59:45 WARN MemoryStore: Not enough space to cache rdd_456_1 in memory! (computed 103.7 MiB so far)
# 22/04/27 10:59:45 WARN BlockManager: Persisting block rdd_456_1 to disk instead.
# 22/04/27 10:59:45 WARN MemoryStore: Not enough space to cache rdd_456_3 in memory! (computed 103.7 MiB so far)
# 22/04/27 10:59:45 WARN BlockManager: Persisting block rdd_456_3 to disk instead.
# 22/04/27 10:59:46 WARN MemoryStore: Not enough space to cache rdd_456_0 in memory! (computed 355.0 MiB so far)
# 22/04/27 10:59:46 WARN BlockManager: Persisting block rdd_456_0 to disk instead.
# 22/04/27 10:59:46 WARN MemoryStore: Not enough space to cache rdd_456_3 in memory! (computed 44.0 MiB so far)
# 22/04/27 10:59:49 WARN MemoryStore: Not enough space to cache rdd_456_2 in memory! (computed 103.7 MiB so far)
# 22/04/27 10:59:49 WARN MemoryStore: Not enough space to cache rdd_456_0 in memory! (computed 155.9 MiB so far)
# 22/04/27 10:59:49 WARN MemoryStore: Not enough space to cache rdd_456_1 in memory! (computed 155.9 MiB so far)
# 22/04/27 10:59:50 WARN DAGScheduler: Broadcasting large task binary with size 2.4 MiB
# 22/04/27 10:59:51 WARN DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 22/04/27 10:59:51 WARN DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 22/04/27 10:59:52 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 22/04/27 10:59:52 WARN MemoryStore: Not enough space to cache rdd_491_0 in memory! (computed 67.5 MiB so far)
# 22/04/27 10:59:52 WARN BlockManager: Persisting block rdd_491_0 to disk instead.
# 22/04/27 10:59:52 WARN MemoryStore: Not enough space to cache rdd_491_1 in memory! (computed 103.7 MiB so far)
# 22/04/27 10:59:52 WARN BlockManager: Persisting block rdd_491_1 to disk instead.
# 22/04/27 10:59:52 WARN MemoryStore: Not enough space to cache rdd_491_3 in memory! (computed 103.7 MiB so far)
# 22/04/27 10:59:52 WARN BlockManager: Persisting block rdd_491_3 to disk instead.
# 22/04/27 10:59:53 WARN MemoryStore: Not enough space to cache rdd_491_2 in memory! (computed 355.0 MiB so far)
# 22/04/27 10:59:53 WARN BlockManager: Persisting block rdd_491_2 to disk instead.
# 22/04/27 10:59:54 WARN MemoryStore: Not enough space to cache rdd_491_3 in memory! (computed 44.0 MiB so far)
# 22/04/27 10:59:56 WARN MemoryStore: Not enough space to cache rdd_491_1 in memory! (computed 103.7 MiB so far)
# 22/04/27 10:59:56 WARN MemoryStore: Not enough space to cache rdd_491_0 in memory! (computed 155.9 MiB so far)
# 22/04/27 10:59:56 WARN MemoryStore: Not enough space to cache rdd_491_2 in memory! (computed 355.2 MiB so far)
# 22/04/27 10:59:58 WARN DAGScheduler: Broadcasting large task binary with size 2.4 MiB
# 22/04/27 10:59:58 WARN DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 22/04/27 10:59:58 WARN DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 22/04/27 10:59:59 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 22/04/27 10:59:59 WARN MemoryStore: Not enough space to cache rdd_526_0 in memory! (computed 67.5 MiB so far)
# 22/04/27 10:59:59 WARN BlockManager: Persisting block rdd_526_0 to disk instead.
# 22/04/27 11:00:00 WARN MemoryStore: Not enough space to cache rdd_526_1 in memory! (computed 103.7 MiB so far)
# 22/04/27 11:00:00 WARN BlockManager: Persisting block rdd_526_1 to disk instead.
# 22/04/27 11:00:00 WARN MemoryStore: Not enough space to cache rdd_526_2 in memory! (computed 103.7 MiB so far)
# 22/04/27 11:00:00 WARN BlockManager: Persisting block rdd_526_2 to disk instead.
# 22/04/27 11:00:03 WARN MemoryStore: Not enough space to cache rdd_526_2 in memory! (computed 29.2 MiB so far)
# 22/04/27 11:00:03 WARN MemoryStore: Not enough space to cache rdd_526_0 in memory! (computed 67.5 MiB so far)
# 22/04/27 11:00:03 WARN MemoryStore: Not enough space to cache rdd_526_1 in memory! (computed 44.0 MiB so far)
# 22/04/27 11:00:05 WARN DAGScheduler: Broadcasting large task binary with size 2.4 MiB
# 22/04/27 11:00:05 WARN DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 22/04/27 11:00:06 WARN DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 22/04/27 11:00:06 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 22/04/27 11:00:06 WARN MemoryStore: Not enough space to cache rdd_561_3 in memory! (computed 67.5 MiB so far)
# 22/04/27 11:00:06 WARN BlockManager: Persisting block rdd_561_3 to disk instead.
# 22/04/27 11:00:07 WARN MemoryStore: Not enough space to cache rdd_561_0 in memory! (computed 103.7 MiB so far)
# 22/04/27 11:00:07 WARN BlockManager: Persisting block rdd_561_0 to disk instead.
# 22/04/27 11:00:07 WARN MemoryStore: Not enough space to cache rdd_561_2 in memory! (computed 103.7 MiB so far)
# 22/04/27 11:00:07 WARN BlockManager: Persisting block rdd_561_2 to disk instead.
# 22/04/27 11:00:07 WARN MemoryStore: Not enough space to cache rdd_561_1 in memory! (computed 355.0 MiB so far)
# 22/04/27 11:00:07 WARN BlockManager: Persisting block rdd_561_1 to disk instead.
# 22/04/27 11:00:08 WARN MemoryStore: Not enough space to cache rdd_561_3 in memory! (computed 44.0 MiB so far)
# 22/04/27 11:00:10 WARN MemoryStore: Not enough space to cache rdd_561_2 in memory! (computed 103.7 MiB so far)
# 22/04/27 11:00:10 WARN MemoryStore: Not enough space to cache rdd_561_1 in memory! (computed 155.9 MiB so far)
# 22/04/27 11:00:10 WARN MemoryStore: Not enough space to cache rdd_561_0 in memory! (computed 355.2 MiB so far)
# 22/04/27 11:00:12 WARN DAGScheduler: Broadcasting large task binary with size 2.4 MiB
# 22/04/27 11:00:12 WARN DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 22/04/27 11:00:13 WARN DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 22/04/27 11:00:13 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 22/04/27 11:00:14 WARN MemoryStore: Not enough space to cache rdd_596_3 in memory! (computed 67.5 MiB so far)
# 22/04/27 11:00:14 WARN BlockManager: Persisting block rdd_596_3 to disk instead.
# 22/04/27 11:00:14 WARN MemoryStore: Not enough space to cache rdd_596_0 in memory! (computed 103.7 MiB so far)
# 22/04/27 11:00:14 WARN BlockManager: Persisting block rdd_596_0 to disk instead.
# 22/04/27 11:00:14 WARN MemoryStore: Not enough space to cache rdd_596_1 in memory! (computed 103.7 MiB so far)
# 22/04/27 11:00:14 WARN BlockManager: Persisting block rdd_596_1 to disk instead.
# 22/04/27 11:00:15 WARN MemoryStore: Not enough space to cache rdd_596_2 in memory! (computed 355.0 MiB so far)
# 22/04/27 11:00:15 WARN BlockManager: Persisting block rdd_596_2 to disk instead.
# 22/04/27 11:00:15 WARN MemoryStore: Not enough space to cache rdd_596_3 in memory! (computed 44.0 MiB so far)
# 22/04/27 11:00:17 WARN MemoryStore: Not enough space to cache rdd_596_1 in memory! (computed 103.7 MiB so far)
# 22/04/27 11:00:17 WARN MemoryStore: Not enough space to cache rdd_596_0 in memory! (computed 155.9 MiB so far)
# 22/04/27 11:00:17 WARN MemoryStore: Not enough space to cache rdd_596_2 in memory! (computed 355.2 MiB so far)
# 22/04/27 11:00:19 WARN DAGScheduler: Broadcasting large task binary with size 2.4 MiB
# 22/04/27 11:00:20 WARN DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 22/04/27 11:00:20 WARN DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 22/04/27 11:00:20 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 22/04/27 11:00:21 WARN MemoryStore: Not enough space to cache rdd_631_0 in memory! (computed 67.5 MiB so far)
# 22/04/27 11:00:21 WARN BlockManager: Persisting block rdd_631_0 to disk instead.
# 22/04/27 11:00:21 WARN MemoryStore: Not enough space to cache rdd_631_3 in memory! (computed 103.7 MiB so far)
# 22/04/27 11:00:21 WARN BlockManager: Persisting block rdd_631_3 to disk instead.
# 22/04/27 11:00:21 WARN MemoryStore: Not enough space to cache rdd_631_2 in memory! (computed 103.7 MiB so far)
# 22/04/27 11:00:21 WARN BlockManager: Persisting block rdd_631_2 to disk instead.
# 22/04/27 11:00:22 WARN MemoryStore: Not enough space to cache rdd_631_1 in memory! (computed 355.0 MiB so far)
# 22/04/27 11:00:22 WARN BlockManager: Persisting block rdd_631_1 to disk instead.
# 22/04/27 11:00:22 WARN MemoryStore: Not enough space to cache rdd_631_3 in memory! (computed 44.0 MiB so far)
# 22/04/27 11:00:24 WARN MemoryStore: Not enough space to cache rdd_631_1 in memory! (computed 103.7 MiB so far)
# 22/04/27 11:00:24 WARN MemoryStore: Not enough space to cache rdd_631_0 in memory! (computed 155.9 MiB so far)
# 22/04/27 11:00:24 WARN MemoryStore: Not enough space to cache rdd_631_2 in memory! (computed 355.2 MiB so far)
# 22/04/27 11:00:26 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 22/04/27 11:00:26 WARN MemoryStore: Not enough space to cache rdd_631_0 in memory! (computed 103.7 MiB so far)
# 22/04/27 11:00:26 WARN MemoryStore: Not enough space to cache rdd_631_3 in memory! (computed 103.7 MiB so far)
# 22/04/27 11:00:26 WARN MemoryStore: Not enough space to cache rdd_631_2 in memory! (computed 103.7 MiB so far)
# 22/04/27 11:00:26 WARN MemoryStore: Not enough space to cache rdd_631_1 in memory! (computed 103.7 MiB so far)
# 22/04/27 11:00:27 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 22/04/27 11:00:28 WARN MemoryStore: Not enough space to cache rdd_631_2 in memory! (computed 103.7 MiB so far)
# 22/04/27 11:00:28 WARN MemoryStore: Not enough space to cache rdd_631_0 in memory! (computed 103.7 MiB so far)
# 22/04/27 11:00:28 WARN MemoryStore: Not enough space to cache rdd_631_3 in memory! (computed 103.7 MiB so far)
# 22/04/27 11:00:28 WARN MemoryStore: Not enough space to cache rdd_631_1 in memory! (computed 103.7 MiB so far)
# 22/04/27 11:00:30 WARN DAGScheduler: Broadcasting large task binary with size 2.4 MiB
# 22/04/27 11:00:30 WARN DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 22/04/27 11:00:30 WARN DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 22/04/27 11:00:31 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 22/04/27 11:00:31 WARN MemoryStore: Not enough space to cache rdd_672_3 in memory! (computed 67.5 MiB so far)
# 22/04/27 11:00:31 WARN BlockManager: Persisting block rdd_672_3 to disk instead.
# 22/04/27 11:00:31 WARN MemoryStore: Not enough space to cache rdd_672_1 in memory! (computed 103.7 MiB so far)
# 22/04/27 11:00:31 WARN BlockManager: Persisting block rdd_672_1 to disk instead.
# 22/04/27 11:00:31 WARN MemoryStore: Not enough space to cache rdd_672_0 in memory! (computed 103.7 MiB so far)
# 22/04/27 11:00:31 WARN BlockManager: Persisting block rdd_672_0 to disk instead.
# 22/04/27 11:00:32 WARN MemoryStore: Not enough space to cache rdd_672_2 in memory! (computed 355.0 MiB so far)
# 22/04/27 11:00:32 WARN BlockManager: Persisting block rdd_672_2 to disk instead.
# 22/04/27 11:00:33 WARN MemoryStore: Not enough space to cache rdd_672_3 in memory! (computed 44.0 MiB so far)
# 22/04/27 11:00:35 WARN MemoryStore: Not enough space to cache rdd_672_1 in memory! (computed 103.7 MiB so far)
# 22/04/27 11:00:35 WARN MemoryStore: Not enough space to cache rdd_672_0 in memory! (computed 155.9 MiB so far)
# 22/04/27 11:00:35 WARN MemoryStore: Not enough space to cache rdd_672_2 in memory! (computed 355.2 MiB so far)
# 22/04/27 11:00:36 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 22/04/27 11:00:37 WARN MemoryStore: Not enough space to cache rdd_672_0 in memory! (computed 103.7 MiB so far)
# 22/04/27 11:00:37 WARN MemoryStore: Not enough space to cache rdd_672_2 in memory! (computed 103.7 MiB so far)
# 22/04/27 11:00:37 WARN MemoryStore: Not enough space to cache rdd_672_1 in memory! (computed 103.7 MiB so far)
# 22/04/27 11:00:37 WARN MemoryStore: Not enough space to cache rdd_672_3 in memory! (computed 103.7 MiB so far)
# 22/04/27 11:00:38 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 22/04/27 11:00:39 WARN MemoryStore: Not enough space to cache rdd_672_3 in memory! (computed 103.7 MiB so far)
# 22/04/27 11:00:39 WARN MemoryStore: Not enough space to cache rdd_672_0 in memory! (computed 103.7 MiB so far)
# 22/04/27 11:00:39 WARN MemoryStore: Not enough space to cache rdd_672_1 in memory! (computed 103.7 MiB so far)
# 22/04/27 11:00:39 WARN MemoryStore: Not enough space to cache rdd_672_2 in memory! (computed 103.7 MiB so far)
# 22/04/27 11:00:40 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 22/04/27 11:00:40 WARN MemoryStore: Not enough space to cache rdd_672_2 in memory! (computed 103.7 MiB so far)
# 22/04/27 11:00:40 WARN MemoryStore: Not enough space to cache rdd_672_3 in memory! (computed 103.7 MiB so far)
# 22/04/27 11:00:40 WARN MemoryStore: Not enough space to cache rdd_672_1 in memory! (computed 103.7 MiB so far)
# 22/04/27 11:00:40 WARN MemoryStore: Not enough space to cache rdd_672_0 in memory! (computed 103.7 MiB so far)
# 22/04/27 11:00:42 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 22/04/27 11:00:43 WARN MemoryStore: Not enough space to cache rdd_672_1 in memory! (computed 103.7 MiB so far)
# 22/04/27 11:00:43 WARN MemoryStore: Not enough space to cache rdd_672_2 in memory! (computed 103.7 MiB so far)
# 22/04/27 11:00:43 WARN MemoryStore: Not enough space to cache rdd_672_0 in memory! (computed 103.7 MiB so far)
# 22/04/27 11:00:43 WARN MemoryStore: Not enough space to cache rdd_672_3 in memory! (computed 103.7 MiB so far)
# 22/04/27 11:00:45 WARN DAGScheduler: Broadcasting large task binary with size 2.4 MiB
# 22/04/27 11:00:45 WARN DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 22/04/27 11:00:45 WARN DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 22/04/27 11:00:46 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 22/04/27 11:00:46 WARN MemoryStore: Not enough space to cache rdd_719_3 in memory! (computed 67.5 MiB so far)
# 22/04/27 11:00:46 WARN BlockManager: Persisting block rdd_719_3 to disk instead.
# 22/04/27 11:00:46 WARN MemoryStore: Not enough space to cache rdd_719_2 in memory! (computed 103.7 MiB so far)
# 22/04/27 11:00:46 WARN MemoryStore: Not enough space to cache rdd_719_1 in memory! (computed 103.7 MiB so far)
# 22/04/27 11:00:46 WARN BlockManager: Persisting block rdd_719_2 to disk instead.
# 22/04/27 11:00:46 WARN BlockManager: Persisting block rdd_719_1 to disk instead.
# 22/04/27 11:00:47 WARN MemoryStore: Not enough space to cache rdd_719_0 in memory! (computed 355.0 MiB so far)
# 22/04/27 11:00:47 WARN BlockManager: Persisting block rdd_719_0 to disk instead.
# 22/04/27 11:00:47 WARN MemoryStore: Not enough space to cache rdd_719_3 in memory! (computed 44.0 MiB so far)
# 22/04/27 11:00:50 WARN MemoryStore: Not enough space to cache rdd_719_2 in memory! (computed 103.7 MiB so far)
# 22/04/27 11:00:50 WARN MemoryStore: Not enough space to cache rdd_719_0 in memory! (computed 155.9 MiB so far)
# 22/04/27 11:00:50 WARN MemoryStore: Not enough space to cache rdd_719_1 in memory! (computed 155.9 MiB so far)
# 22/04/27 11:00:51 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 22/04/27 11:00:51 WARN MemoryStore: Not enough space to cache rdd_719_0 in memory! (computed 103.7 MiB so far)
# 22/04/27 11:00:51 WARN MemoryStore: Not enough space to cache rdd_719_3 in memory! (computed 103.7 MiB so far)
# 22/04/27 11:00:51 WARN MemoryStore: Not enough space to cache rdd_719_2 in memory! (computed 103.7 MiB so far)
# 22/04/27 11:00:51 WARN MemoryStore: Not enough space to cache rdd_719_1 in memory! (computed 103.7 MiB so far)
# 22/04/27 11:00:53 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 22/04/27 11:00:53 WARN MemoryStore: Not enough space to cache rdd_719_3 in memory! (computed 103.7 MiB so far)
# 22/04/27 11:00:53 WARN MemoryStore: Not enough space to cache rdd_719_2 in memory! (computed 103.7 MiB so far)
# 22/04/27 11:00:53 WARN MemoryStore: Not enough space to cache rdd_719_0 in memory! (computed 103.7 MiB so far)
# 22/04/27 11:00:53 WARN MemoryStore: Not enough space to cache rdd_719_1 in memory! (computed 103.7 MiB so far)
# 22/04/27 11:00:55 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 22/04/27 11:00:55 WARN MemoryStore: Not enough space to cache rdd_719_1 in memory! (computed 103.7 MiB so far)
# 22/04/27 11:00:55 WARN MemoryStore: Not enough space to cache rdd_719_2 in memory! (computed 103.7 MiB so far)
# 22/04/27 11:00:55 WARN MemoryStore: Not enough space to cache rdd_719_0 in memory! (computed 103.7 MiB so far)
# 22/04/27 11:00:55 WARN MemoryStore: Not enough space to cache rdd_719_3 in memory! (computed 103.7 MiB so far)
# 22/04/27 11:00:57 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 22/04/27 11:00:57 WARN MemoryStore: Not enough space to cache rdd_719_3 in memory! (computed 103.7 MiB so far)
# 22/04/27 11:00:57 WARN MemoryStore: Not enough space to cache rdd_719_0 in memory! (computed 103.7 MiB so far)
# 22/04/27 11:00:57 WARN MemoryStore: Not enough space to cache rdd_719_1 in memory! (computed 103.7 MiB so far)
# 22/04/27 11:00:57 WARN MemoryStore: Not enough space to cache rdd_719_2 in memory! (computed 103.7 MiB so far)
# 22/04/27 11:00:59 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 22/04/27 11:00:59 WARN MemoryStore: Not enough space to cache rdd_719_3 in memory! (computed 103.7 MiB so far)
# 22/04/27 11:00:59 WARN MemoryStore: Not enough space to cache rdd_719_0 in memory! (computed 103.7 MiB so far)
# 22/04/27 11:00:59 WARN MemoryStore: Not enough space to cache rdd_719_2 in memory! (computed 103.7 MiB so far)
# 22/04/27 11:00:59 WARN MemoryStore: Not enough space to cache rdd_719_1 in memory! (computed 103.7 MiB so far)
# 22/04/27 11:01:01 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 22/04/27 11:01:02 WARN MemoryStore: Not enough space to cache rdd_719_3 in memory! (computed 103.7 MiB so far)
# 22/04/27 11:01:02 WARN MemoryStore: Not enough space to cache rdd_719_2 in memory! (computed 103.7 MiB so far)
# 22/04/27 11:01:02 WARN MemoryStore: Not enough space to cache rdd_719_1 in memory! (computed 103.7 MiB so far)
# 22/04/27 11:01:02 WARN MemoryStore: Not enough space to cache rdd_719_0 in memory! (computed 103.7 MiB so far)
# 22/04/27 11:01:04 WARN DAGScheduler: Broadcasting large task binary with size 2.4 MiB
# 22/04/27 11:01:05 WARN DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 22/04/27 11:01:05 WARN DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 22/04/27 11:01:06 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 22/04/27 11:01:06 WARN MemoryStore: Not enough space to cache rdd_772_0 in memory! (computed 67.5 MiB so far)
# 22/04/27 11:01:06 WARN BlockManager: Persisting block rdd_772_0 to disk instead.
# 22/04/27 11:01:06 WARN MemoryStore: Not enough space to cache rdd_772_3 in memory! (computed 103.7 MiB so far)
# 22/04/27 11:01:06 WARN BlockManager: Persisting block rdd_772_3 to disk instead.
# 22/04/27 11:01:06 WARN MemoryStore: Not enough space to cache rdd_772_1 in memory! (computed 103.7 MiB so far)
# 22/04/27 11:01:06 WARN BlockManager: Persisting block rdd_772_1 to disk instead.
# 22/04/27 11:01:07 WARN MemoryStore: Not enough space to cache rdd_772_2 in memory! (computed 355.0 MiB so far)
# 22/04/27 11:01:07 WARN BlockManager: Persisting block rdd_772_2 to disk instead.
# 22/04/27 11:01:07 WARN MemoryStore: Not enough space to cache rdd_772_3 in memory! (computed 44.0 MiB so far)
# 22/04/27 11:01:10 WARN MemoryStore: Not enough space to cache rdd_772_1 in memory! (computed 103.7 MiB so far)
# 22/04/27 11:01:10 WARN MemoryStore: Not enough space to cache rdd_772_0 in memory! (computed 155.9 MiB so far)
# 22/04/27 11:01:10 WARN MemoryStore: Not enough space to cache rdd_772_2 in memory! (computed 355.2 MiB so far)
# 22/04/27 11:01:11 WARN DAGScheduler: Broadcasting large task binary with size 2.4 MiB
# 22/04/27 11:01:12 WARN DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 22/04/27 11:01:12 WARN DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 22/04/27 11:01:13 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 22/04/27 11:01:13 WARN MemoryStore: Not enough space to cache rdd_807_2 in memory! (computed 67.5 MiB so far)
# 22/04/27 11:01:13 WARN BlockManager: Persisting block rdd_807_2 to disk instead.
# 22/04/27 11:01:13 WARN MemoryStore: Not enough space to cache rdd_807_1 in memory! (computed 103.7 MiB so far)
# 22/04/27 11:01:13 WARN BlockManager: Persisting block rdd_807_1 to disk instead.
# 22/04/27 11:01:13 WARN MemoryStore: Not enough space to cache rdd_807_3 in memory! (computed 103.7 MiB so far)
# 22/04/27 11:01:13 WARN BlockManager: Persisting block rdd_807_3 to disk instead.
# 22/04/27 11:01:14 WARN MemoryStore: Not enough space to cache rdd_807_0 in memory! (computed 355.0 MiB so far)
# 22/04/27 11:01:14 WARN BlockManager: Persisting block rdd_807_0 to disk instead.
# 22/04/27 11:01:15 WARN MemoryStore: Not enough space to cache rdd_807_3 in memory! (computed 44.0 MiB so far)
# 22/04/27 11:01:17 WARN MemoryStore: Not enough space to cache rdd_807_2 in memory! (computed 103.7 MiB so far)
# 22/04/27 11:01:17 WARN MemoryStore: Not enough space to cache rdd_807_0 in memory! (computed 155.9 MiB so far)
# 22/04/27 11:01:17 WARN MemoryStore: Not enough space to cache rdd_807_1 in memory! (computed 355.2 MiB so far)
# 22/04/27 11:01:19 WARN DAGScheduler: Broadcasting large task binary with size 2.4 MiB
# 22/04/27 11:01:19 WARN DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 22/04/27 11:01:19 WARN DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 22/04/27 11:01:20 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 22/04/27 11:01:20 WARN MemoryStore: Not enough space to cache rdd_842_0 in memory! (computed 67.5 MiB so far)
# 22/04/27 11:01:20 WARN BlockManager: Persisting block rdd_842_0 to disk instead.
# 22/04/27 11:01:21 WARN MemoryStore: Not enough space to cache rdd_842_1 in memory! (computed 103.7 MiB so far)
# 22/04/27 11:01:21 WARN MemoryStore: Not enough space to cache rdd_842_2 in memory! (computed 103.7 MiB so far)
# 22/04/27 11:01:21 WARN BlockManager: Persisting block rdd_842_2 to disk instead.
# 22/04/27 11:01:21 WARN BlockManager: Persisting block rdd_842_1 to disk instead.
# 22/04/27 11:01:24 WARN MemoryStore: Not enough space to cache rdd_842_0 in memory! (computed 67.5 MiB so far)
# 22/04/27 11:01:24 WARN MemoryStore: Not enough space to cache rdd_842_2 in memory! (computed 29.2 MiB so far)
# 22/04/27 11:01:24 WARN MemoryStore: Not enough space to cache rdd_842_1 in memory! (computed 103.7 MiB so far)
# 22/04/27 11:01:26 WARN DAGScheduler: Broadcasting large task binary with size 2.4 MiB
# 22/04/27 11:01:26 WARN DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 22/04/27 11:01:27 WARN DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 22/04/27 11:01:28 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 22/04/27 11:01:28 WARN MemoryStore: Not enough space to cache rdd_877_2 in memory! (computed 67.5 MiB so far)
# 22/04/27 11:01:28 WARN BlockManager: Persisting block rdd_877_2 to disk instead.
# 22/04/27 11:01:28 WARN MemoryStore: Not enough space to cache rdd_877_3 in memory! (computed 103.7 MiB so far)
# 22/04/27 11:01:28 WARN BlockManager: Persisting block rdd_877_3 to disk instead.
# 22/04/27 11:01:28 WARN MemoryStore: Not enough space to cache rdd_877_0 in memory! (computed 103.7 MiB so far)
# 22/04/27 11:01:28 WARN BlockManager: Persisting block rdd_877_0 to disk instead.
# 22/04/27 11:01:29 WARN MemoryStore: Not enough space to cache rdd_877_1 in memory! (computed 355.0 MiB so far)
# 22/04/27 11:01:29 WARN BlockManager: Persisting block rdd_877_1 to disk instead.
# 22/04/27 11:01:29 WARN MemoryStore: Not enough space to cache rdd_877_3 in memory! (computed 44.0 MiB so far)
# 22/04/27 11:01:32 WARN MemoryStore: Not enough space to cache rdd_877_2 in memory! (computed 103.7 MiB so far)
# 22/04/27 11:01:32 WARN MemoryStore: Not enough space to cache rdd_877_0 in memory! (computed 155.9 MiB so far)
# 22/04/27 11:01:32 WARN MemoryStore: Not enough space to cache rdd_877_1 in memory! (computed 155.9 MiB so far)
# 22/04/27 11:01:33 WARN DAGScheduler: Broadcasting large task binary with size 2.4 MiB
# 22/04/27 11:01:34 WARN DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 22/04/27 11:01:34 WARN DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 22/04/27 11:01:35 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 22/04/27 11:01:35 WARN MemoryStore: Not enough space to cache rdd_912_2 in memory! (computed 67.5 MiB so far)
# 22/04/27 11:01:35 WARN BlockManager: Persisting block rdd_912_2 to disk instead.
# 22/04/27 11:01:35 WARN MemoryStore: Not enough space to cache rdd_912_3 in memory! (computed 103.7 MiB so far)
# 22/04/27 11:01:35 WARN BlockManager: Persisting block rdd_912_3 to disk instead.
# 22/04/27 11:01:35 WARN MemoryStore: Not enough space to cache rdd_912_0 in memory! (computed 103.7 MiB so far)
# 22/04/27 11:01:35 WARN BlockManager: Persisting block rdd_912_0 to disk instead.
# 22/04/27 11:01:36 WARN MemoryStore: Not enough space to cache rdd_912_1 in memory! (computed 355.0 MiB so far)
# 22/04/27 11:01:36 WARN BlockManager: Persisting block rdd_912_1 to disk instead.
# 22/04/27 11:01:36 WARN MemoryStore: Not enough space to cache rdd_912_3 in memory! (computed 44.0 MiB so far)
# 22/04/27 11:01:38 WARN MemoryStore: Not enough space to cache rdd_912_1 in memory! (computed 103.7 MiB so far)
# 22/04/27 11:01:38 WARN MemoryStore: Not enough space to cache rdd_912_2 in memory! (computed 155.9 MiB so far)
# 22/04/27 11:01:39 WARN MemoryStore: Not enough space to cache rdd_912_0 in memory! (computed 355.2 MiB so far)
# 22/04/27 11:01:40 WARN DAGScheduler: Broadcasting large task binary with size 2.4 MiB
# 22/04/27 11:01:41 WARN DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 22/04/27 11:01:41 WARN DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 22/04/27 11:01:42 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 22/04/27 11:01:42 WARN MemoryStore: Not enough space to cache rdd_947_3 in memory! (computed 67.5 MiB so far)
# 22/04/27 11:01:42 WARN BlockManager: Persisting block rdd_947_3 to disk instead.
# 22/04/27 11:01:42 WARN MemoryStore: Not enough space to cache rdd_947_0 in memory! (computed 103.7 MiB so far)
# 22/04/27 11:01:42 WARN BlockManager: Persisting block rdd_947_0 to disk instead.
# 22/04/27 11:01:42 WARN MemoryStore: Not enough space to cache rdd_947_1 in memory! (computed 103.7 MiB so far)
# 22/04/27 11:01:42 WARN BlockManager: Persisting block rdd_947_1 to disk instead.
# 22/04/27 11:01:43 WARN MemoryStore: Not enough space to cache rdd_947_2 in memory! (computed 355.0 MiB so far)
# 22/04/27 11:01:43 WARN BlockManager: Persisting block rdd_947_2 to disk instead.
# 22/04/27 11:01:43 WARN MemoryStore: Not enough space to cache rdd_947_3 in memory! (computed 44.0 MiB so far)
# 22/04/27 11:01:45 WARN MemoryStore: Not enough space to cache rdd_947_1 in memory! (computed 103.7 MiB so far)
# 22/04/27 11:01:45 WARN MemoryStore: Not enough space to cache rdd_947_0 in memory! (computed 155.9 MiB so far)
# 22/04/27 11:01:46 WARN MemoryStore: Not enough space to cache rdd_947_2 in memory! (computed 355.2 MiB so far)
# 22/04/27 11:01:47 WARN DAGScheduler: Broadcasting large task binary with size 2.4 MiB
# 22/04/27 11:01:48 WARN DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 22/04/27 11:01:48 WARN DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 22/04/27 11:01:49 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 22/04/27 11:01:49 WARN MemoryStore: Not enough space to cache rdd_982_2 in memory! (computed 67.5 MiB so far)
# 22/04/27 11:01:49 WARN BlockManager: Persisting block rdd_982_2 to disk instead.
# 22/04/27 11:01:49 WARN MemoryStore: Not enough space to cache rdd_982_1 in memory! (computed 103.7 MiB so far)
# 22/04/27 11:01:49 WARN BlockManager: Persisting block rdd_982_1 to disk instead.
# 22/04/27 11:01:49 WARN MemoryStore: Not enough space to cache rdd_982_3 in memory! (computed 103.7 MiB so far)
# 22/04/27 11:01:49 WARN BlockManager: Persisting block rdd_982_3 to disk instead.
# 22/04/27 11:01:50 WARN MemoryStore: Not enough space to cache rdd_982_0 in memory! (computed 355.0 MiB so far)
# 22/04/27 11:01:50 WARN BlockManager: Persisting block rdd_982_0 to disk instead.
# 22/04/27 11:01:50 WARN MemoryStore: Not enough space to cache rdd_982_3 in memory! (computed 44.0 MiB so far)
# 22/04/27 11:01:53 WARN MemoryStore: Not enough space to cache rdd_982_2 in memory! (computed 103.7 MiB so far)
# 22/04/27 11:01:53 WARN MemoryStore: Not enough space to cache rdd_982_0 in memory! (computed 155.9 MiB so far)
# 22/04/27 11:01:53 WARN MemoryStore: Not enough space to cache rdd_982_1 in memory! (computed 355.2 MiB so far)
# 22/04/27 11:01:55 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 22/04/27 11:01:55 WARN MemoryStore: Not enough space to cache rdd_982_1 in memory! (computed 103.7 MiB so far)
# 22/04/27 11:01:55 WARN MemoryStore: Not enough space to cache rdd_982_2 in memory! (computed 103.7 MiB so far)
# 22/04/27 11:01:55 WARN MemoryStore: Not enough space to cache rdd_982_3 in memory! (computed 103.7 MiB so far)
# 22/04/27 11:01:55 WARN MemoryStore: Not enough space to cache rdd_982_0 in memory! (computed 103.7 MiB so far)
# 22/04/27 11:01:56 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 22/04/27 11:01:57 WARN MemoryStore: Not enough space to cache rdd_982_2 in memory! (computed 103.7 MiB so far)
# 22/04/27 11:01:57 WARN MemoryStore: Not enough space to cache rdd_982_0 in memory! (computed 103.7 MiB so far)
# 22/04/27 11:01:57 WARN MemoryStore: Not enough space to cache rdd_982_1 in memory! (computed 103.7 MiB so far)
# 22/04/27 11:01:57 WARN MemoryStore: Not enough space to cache rdd_982_3 in memory! (computed 103.7 MiB so far)
# 22/04/27 11:01:58 WARN DAGScheduler: Broadcasting large task binary with size 2.4 MiB
# 22/04/27 11:01:59 WARN DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 22/04/27 11:01:59 WARN DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 22/04/27 11:02:00 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 22/04/27 11:02:00 WARN MemoryStore: Not enough space to cache rdd_1023_2 in memory! (computed 67.5 MiB so far)
# 22/04/27 11:02:00 WARN BlockManager: Persisting block rdd_1023_2 to disk instead.
# 22/04/27 11:02:00 WARN MemoryStore: Not enough space to cache rdd_1023_0 in memory! (computed 103.7 MiB so far)
# 22/04/27 11:02:00 WARN BlockManager: Persisting block rdd_1023_0 to disk instead.
# 22/04/27 11:02:00 WARN MemoryStore: Not enough space to cache rdd_1023_1 in memory! (computed 103.7 MiB so far)
# 22/04/27 11:02:00 WARN BlockManager: Persisting block rdd_1023_1 to disk instead.
# 22/04/27 11:02:03 WARN MemoryStore: Not enough space to cache rdd_1023_1 in memory! (computed 29.2 MiB so far)
# 22/04/27 11:02:03 WARN MemoryStore: Not enough space to cache rdd_1023_0 in memory! (computed 67.5 MiB so far)
# 22/04/27 11:02:03 WARN MemoryStore: Not enough space to cache rdd_1023_2 in memory! (computed 44.0 MiB so far)
# 22/04/27 11:02:05 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 22/04/27 11:02:05 WARN MemoryStore: Not enough space to cache rdd_1023_1 in memory! (computed 44.0 MiB so far)
# 22/04/27 11:02:05 WARN MemoryStore: Not enough space to cache rdd_1023_2 in memory! (computed 44.0 MiB so far)
# 22/04/27 11:02:05 WARN MemoryStore: Not enough space to cache rdd_1023_0 in memory! (computed 44.0 MiB so far)
# 22/04/27 11:02:07 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 22/04/27 11:02:07 WARN MemoryStore: Not enough space to cache rdd_1023_2 in memory! (computed 44.0 MiB so far)
# 22/04/27 11:02:07 WARN MemoryStore: Not enough space to cache rdd_1023_1 in memory! (computed 44.0 MiB so far)
# 22/04/27 11:02:07 WARN MemoryStore: Not enough space to cache rdd_1023_0 in memory! (computed 44.0 MiB so far)
# 22/04/27 11:02:09 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 22/04/27 11:02:09 WARN MemoryStore: Not enough space to cache rdd_1023_2 in memory! (computed 44.0 MiB so far)
# 22/04/27 11:02:09 WARN MemoryStore: Not enough space to cache rdd_1023_0 in memory! (computed 44.0 MiB so far)
# 22/04/27 11:02:09 WARN MemoryStore: Not enough space to cache rdd_1023_1 in memory! (computed 44.0 MiB so far)
# 22/04/27 11:02:11 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 22/04/27 11:02:11 WARN MemoryStore: Not enough space to cache rdd_1023_2 in memory! (computed 44.0 MiB so far)
# 22/04/27 11:02:11 WARN MemoryStore: Not enough space to cache rdd_1023_0 in memory! (computed 44.0 MiB so far)
# 22/04/27 11:02:11 WARN MemoryStore: Not enough space to cache rdd_1023_1 in memory! (computed 44.0 MiB so far)
# 22/04/27 11:02:14 WARN DAGScheduler: Broadcasting large task binary with size 2.4 MiB
# 22/04/27 11:02:14 WARN DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 22/04/27 11:02:14 WARN DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 22/04/27 11:02:15 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 22/04/27 11:02:15 WARN MemoryStore: Not enough space to cache rdd_1070_3 in memory! (computed 67.5 MiB so far)
# 22/04/27 11:02:15 WARN BlockManager: Persisting block rdd_1070_3 to disk instead.
# 22/04/27 11:02:15 WARN MemoryStore: Not enough space to cache rdd_1070_0 in memory! (computed 103.7 MiB so far)
# 22/04/27 11:02:15 WARN MemoryStore: Not enough space to cache rdd_1070_1 in memory! (computed 103.7 MiB so far)
# 22/04/27 11:02:15 WARN BlockManager: Persisting block rdd_1070_0 to disk instead.
# 22/04/27 11:02:15 WARN BlockManager: Persisting block rdd_1070_1 to disk instead.
# 22/04/27 11:02:16 WARN MemoryStore: Not enough space to cache rdd_1070_2 in memory! (computed 355.0 MiB so far)
# 22/04/27 11:02:16 WARN BlockManager: Persisting block rdd_1070_2 to disk instead.
# 22/04/27 11:02:17 WARN MemoryStore: Not enough space to cache rdd_1070_3 in memory! (computed 44.0 MiB so far)
# 22/04/27 11:02:19 WARN MemoryStore: Not enough space to cache rdd_1070_1 in memory! (computed 103.7 MiB so far)
# 22/04/27 11:02:19 WARN MemoryStore: Not enough space to cache rdd_1070_0 in memory! (computed 155.9 MiB so far)
# 22/04/27 11:02:19 WARN MemoryStore: Not enough space to cache rdd_1070_2 in memory! (computed 355.2 MiB so far)
# 22/04/27 11:02:21 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 22/04/27 11:02:21 WARN MemoryStore: Not enough space to cache rdd_1070_3 in memory! (computed 103.7 MiB so far)
# 22/04/27 11:02:21 WARN MemoryStore: Not enough space to cache rdd_1070_1 in memory! (computed 103.7 MiB so far)
# 22/04/27 11:02:21 WARN MemoryStore: Not enough space to cache rdd_1070_0 in memory! (computed 103.7 MiB so far)
# 22/04/27 11:02:21 WARN MemoryStore: Not enough space to cache rdd_1070_2 in memory! (computed 103.7 MiB so far)
# 22/04/27 11:02:23 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 22/04/27 11:02:23 WARN MemoryStore: Not enough space to cache rdd_1070_0 in memory! (computed 103.7 MiB so far)
# 22/04/27 11:02:23 WARN MemoryStore: Not enough space to cache rdd_1070_2 in memory! (computed 103.7 MiB so far)
# 22/04/27 11:02:23 WARN MemoryStore: Not enough space to cache rdd_1070_1 in memory! (computed 103.7 MiB so far)
# 22/04/27 11:02:23 WARN MemoryStore: Not enough space to cache rdd_1070_3 in memory! (computed 103.7 MiB so far)
# 22/04/27 11:02:25 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# ...
# 22/04/27 11:35:05 WARN MemoryStore: Not enough space to cache rdd_8471_0 in memory! (computed 44.0 MiB so far)
# 22/04/27 11:35:05 WARN MemoryStore: Not enough space to cache rdd_8471_1 in memory! (computed 44.0 MiB so far)
# 22/04/27 11:35:05 WARN MemoryStore: Not enough space to cache rdd_8471_2 in memory! (computed 44.0 MiB so far)
# 22/04/27 11:35:07 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 22/04/27 11:35:07 WARN MemoryStore: Not enough space to cache rdd_8471_0 in memory! (computed 44.0 MiB so far)
# 22/04/27 11:35:07 WARN MemoryStore: Not enough space to cache rdd_8471_1 in memory! (computed 44.0 MiB so far)
# 22/04/27 11:35:07 WARN MemoryStore: Not enough space to cache rdd_8471_2 in memory! (computed 44.0 MiB so far)
# 22/04/27 11:35:09 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 22/04/27 11:35:09 WARN MemoryStore: Not enough space to cache rdd_8471_1 in memory! (computed 44.0 MiB so far)
# 22/04/27 11:35:09 WARN MemoryStore: Not enough space to cache rdd_8471_2 in memory! (computed 44.0 MiB so far)
# 22/04/27 11:35:09 WARN MemoryStore: Not enough space to cache rdd_8471_0 in memory! (computed 44.0 MiB so far)
# 22/04/27 11:35:11 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 22/04/27 11:35:11 WARN MemoryStore: Not enough space to cache rdd_8471_1 in memory! (computed 44.0 MiB so far)
# 22/04/27 11:35:11 WARN MemoryStore: Not enough space to cache rdd_8471_2 in memory! (computed 44.0 MiB so far)
# 22/04/27 11:35:11 WARN MemoryStore: Not enough space to cache rdd_8471_0 in memory! (computed 44.0 MiB so far)
# 22/04/27 11:35:14 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 22/04/27 11:35:14 WARN MemoryStore: Not enough space to cache rdd_8471_1 in memory! (computed 44.0 MiB so far)
# 22/04/27 11:35:14 WARN MemoryStore: Not enough space to cache rdd_8471_2 in memory! (computed 44.0 MiB so far)
# 22/04/27 11:35:14 WARN MemoryStore: Not enough space to cache rdd_8471_0 in memory! (computed 44.0 MiB so far)
# 22/04/27 11:35:16 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 22/04/27 11:35:16 WARN MemoryStore: Not enough space to cache rdd_8471_2 in memory! (computed 44.0 MiB so far)
# 22/04/27 11:35:16 WARN MemoryStore: Not enough space to cache rdd_8471_1 in memory! (computed 44.0 MiB so far)
# 22/04/27 11:35:16 WARN MemoryStore: Not enough space to cache rdd_8471_0 in memory! (computed 44.0 MiB so far)
# 22/04/27 11:35:19 WARN DAGScheduler: Broadcasting large task binary with size 2.4 MiB
# 22/04/27 11:35:20 WARN DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 22/04/27 11:35:20 WARN DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 22/04/27 11:35:20 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 22/04/27 11:35:21 WARN MemoryStore: Not enough space to cache rdd_8524_3 in memory! (computed 67.5 MiB so far)
# 22/04/27 11:35:21 WARN BlockManager: Persisting block rdd_8524_3 to disk instead.
# 22/04/27 11:35:21 WARN MemoryStore: Not enough space to cache rdd_8524_2 in memory! (computed 103.7 MiB so far)
# 22/04/27 11:35:21 WARN BlockManager: Persisting block rdd_8524_2 to disk instead.
# 22/04/27 11:35:21 WARN MemoryStore: Not enough space to cache rdd_8524_1 in memory! (computed 103.7 MiB so far)
# 22/04/27 11:35:21 WARN BlockManager: Persisting block rdd_8524_1 to disk instead.
# 22/04/27 11:35:22 WARN MemoryStore: Not enough space to cache rdd_8524_0 in memory! (computed 355.0 MiB so far)
# 22/04/27 11:35:22 WARN BlockManager: Persisting block rdd_8524_0 to disk instead.
# 22/04/27 11:35:22 WARN MemoryStore: Not enough space to cache rdd_8524_3 in memory! (computed 44.0 MiB so far)
# 22/04/27 11:35:24 WARN MemoryStore: Not enough space to cache rdd_8524_1 in memory! (computed 103.7 MiB so far)
# 22/04/27 11:35:24 WARN MemoryStore: Not enough space to cache rdd_8524_2 in memory! (computed 155.9 MiB so far)
# 22/04/27 11:35:25 WARN MemoryStore: Not enough space to cache rdd_8524_0 in memory! (computed 155.9 MiB so far)
# 22/04/27 11:35:26 WARN DAGScheduler: Broadcasting large task binary with size 2.4 MiB
# 22/04/27 11:35:27 WARN DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 22/04/27 11:35:27 WARN DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 22/04/27 11:35:28 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 22/04/27 11:35:28 WARN MemoryStore: Not enough space to cache rdd_8559_3 in memory! (computed 67.5 MiB so far)
# 22/04/27 11:35:28 WARN BlockManager: Persisting block rdd_8559_3 to disk instead.
# 22/04/27 11:35:28 WARN MemoryStore: Not enough space to cache rdd_8559_2 in memory! (computed 103.7 MiB so far)
# 22/04/27 11:35:28 WARN BlockManager: Persisting block rdd_8559_2 to disk instead.
# 22/04/27 11:35:28 WARN MemoryStore: Not enough space to cache rdd_8559_1 in memory! (computed 103.7 MiB so far)
# 22/04/27 11:35:28 WARN BlockManager: Persisting block rdd_8559_1 to disk instead.
# 22/04/27 11:35:29 WARN MemoryStore: Not enough space to cache rdd_8559_0 in memory! (computed 355.0 MiB so far)
# 22/04/27 11:35:29 WARN BlockManager: Persisting block rdd_8559_0 to disk instead.
# 22/04/27 11:35:29 WARN MemoryStore: Not enough space to cache rdd_8559_3 in memory! (computed 44.0 MiB so far)
# 22/04/27 11:35:32 WARN MemoryStore: Not enough space to cache rdd_8559_1 in memory! (computed 103.7 MiB so far)
# 22/04/27 11:35:32 WARN MemoryStore: Not enough space to cache rdd_8559_0 in memory! (computed 155.9 MiB so far)
# 22/04/27 11:35:32 WARN MemoryStore: Not enough space to cache rdd_8559_2 in memory! (computed 155.9 MiB so far)
# 22/04/27 11:35:34 WARN DAGScheduler: Broadcasting large task binary with size 2.4 MiB
# 22/04/27 11:35:34 WARN DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 22/04/27 11:35:34 WARN DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 22/04/27 11:35:35 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 22/04/27 11:35:35 WARN MemoryStore: Not enough space to cache rdd_8594_0 in memory! (computed 67.5 MiB so far)
# 22/04/27 11:35:35 WARN BlockManager: Persisting block rdd_8594_0 to disk instead.
# 22/04/27 11:35:36 WARN MemoryStore: Not enough space to cache rdd_8594_2 in memory! (computed 103.7 MiB so far)
# 22/04/27 11:35:36 WARN BlockManager: Persisting block rdd_8594_2 to disk instead.
# 22/04/27 11:35:36 WARN MemoryStore: Not enough space to cache rdd_8594_1 in memory! (computed 103.7 MiB so far)
# 22/04/27 11:35:36 WARN BlockManager: Persisting block rdd_8594_1 to disk instead.
# 22/04/27 11:35:39 WARN MemoryStore: Not enough space to cache rdd_8594_1 in memory! (computed 29.2 MiB so far)
# 22/04/27 11:35:39 WARN MemoryStore: Not enough space to cache rdd_8594_0 in memory! (computed 44.0 MiB so far)
# 22/04/27 11:35:39 WARN MemoryStore: Not enough space to cache rdd_8594_2 in memory! (computed 67.5 MiB so far)
# 22/04/27 11:35:41 WARN DAGScheduler: Broadcasting large task binary with size 2.4 MiB
# 22/04/27 11:35:41 WARN DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 22/04/27 11:35:41 WARN DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 22/04/27 11:35:42 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 22/04/27 11:35:42 WARN MemoryStore: Not enough space to cache rdd_8629_0 in memory! (computed 67.5 MiB so far)
# 22/04/27 11:35:42 WARN BlockManager: Persisting block rdd_8629_0 to disk instead.
# 22/04/27 11:35:43 WARN MemoryStore: Not enough space to cache rdd_8629_2 in memory! (computed 103.7 MiB so far)
# 22/04/27 11:35:43 WARN BlockManager: Persisting block rdd_8629_2 to disk instead.
# 22/04/27 11:35:43 WARN MemoryStore: Not enough space to cache rdd_8629_1 in memory! (computed 103.7 MiB so far)
# 22/04/27 11:35:43 WARN BlockManager: Persisting block rdd_8629_1 to disk instead.
# 22/04/27 11:35:46 WARN MemoryStore: Not enough space to cache rdd_8629_1 in memory! (computed 29.2 MiB so far)
# 22/04/27 11:35:46 WARN MemoryStore: Not enough space to cache rdd_8629_0 in memory! (computed 44.0 MiB so far)
# 22/04/27 11:35:46 WARN MemoryStore: Not enough space to cache rdd_8629_2 in memory! (computed 103.7 MiB so far)
# 22/04/27 11:35:48 WARN DAGScheduler: Broadcasting large task binary with size 2.4 MiB
# 22/04/27 11:35:48 WARN DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 22/04/27 11:35:48 WARN DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 22/04/27 11:35:49 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 22/04/27 11:35:49 WARN MemoryStore: Not enough space to cache rdd_8664_3 in memory! (computed 67.5 MiB so far)
# 22/04/27 11:35:49 WARN BlockManager: Persisting block rdd_8664_3 to disk instead.
# 22/04/27 11:35:50 WARN MemoryStore: Not enough space to cache rdd_8664_1 in memory! (computed 103.7 MiB so far)
# 22/04/27 11:35:50 WARN BlockManager: Persisting block rdd_8664_1 to disk instead.
# 22/04/27 11:35:50 WARN MemoryStore: Not enough space to cache rdd_8664_0 in memory! (computed 103.7 MiB so far)
# 22/04/27 11:35:50 WARN BlockManager: Persisting block rdd_8664_0 to disk instead.
# 22/04/27 11:35:51 WARN MemoryStore: Not enough space to cache rdd_8664_2 in memory! (computed 355.0 MiB so far)
# 22/04/27 11:35:51 WARN BlockManager: Persisting block rdd_8664_2 to disk instead.
# 22/04/27 11:35:51 WARN MemoryStore: Not enough space to cache rdd_8664_3 in memory! (computed 44.0 MiB so far)
# 22/04/27 11:35:53 WARN MemoryStore: Not enough space to cache rdd_8664_1 in memory! (computed 103.7 MiB so far)
# 22/04/27 11:35:53 WARN MemoryStore: Not enough space to cache rdd_8664_2 in memory! (computed 155.9 MiB so far)
# 22/04/27 11:35:54 WARN MemoryStore: Not enough space to cache rdd_8664_0 in memory! (computed 355.2 MiB so far)
# 22/04/27 11:35:55 WARN DAGScheduler: Broadcasting large task binary with size 2.4 MiB
# 22/04/27 11:35:56 WARN DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 22/04/27 11:35:56 WARN DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 22/04/27 11:35:56 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 22/04/27 11:35:57 WARN MemoryStore: Not enough space to cache rdd_8699_2 in memory! (computed 67.5 MiB so far)
# 22/04/27 11:35:57 WARN BlockManager: Persisting block rdd_8699_2 to disk instead.
# 22/04/27 11:35:57 WARN MemoryStore: Not enough space to cache rdd_8699_1 in memory! (computed 103.7 MiB so far)
# 22/04/27 11:35:57 WARN BlockManager: Persisting block rdd_8699_1 to disk instead.
# 22/04/27 11:35:57 WARN MemoryStore: Not enough space to cache rdd_8699_3 in memory! (computed 103.7 MiB so far)
# 22/04/27 11:35:57 WARN BlockManager: Persisting block rdd_8699_3 to disk instead.
# 22/04/27 11:35:58 WARN MemoryStore: Not enough space to cache rdd_8699_0 in memory! (computed 355.0 MiB so far)
# 22/04/27 11:35:58 WARN BlockManager: Persisting block rdd_8699_0 to disk instead.
# 22/04/27 11:35:58 WARN MemoryStore: Not enough space to cache rdd_8699_3 in memory! (computed 44.0 MiB so far)
# 22/04/27 11:36:00 WARN MemoryStore: Not enough space to cache rdd_8699_1 in memory! (computed 103.7 MiB so far)
# 22/04/27 11:36:00 WARN MemoryStore: Not enough space to cache rdd_8699_0 in memory! (computed 155.9 MiB so far)
# 22/04/27 11:36:01 WARN MemoryStore: Not enough space to cache rdd_8699_2 in memory! (computed 155.9 MiB so far)
# 22/04/27 11:36:02 WARN DAGScheduler: Broadcasting large task binary with size 2.4 MiB
# 22/04/27 11:36:03 WARN DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 22/04/27 11:36:05 WARN DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 22/04/27 11:36:07 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 22/04/27 11:36:09 WARN MemoryStore: Not enough space to cache rdd_8732_3 in memory! (computed 233.8 MiB so far)
# 22/04/27 11:36:09 WARN BlockManager: Persisting block rdd_8732_3 to disk instead.
# 22/04/27 11:36:10 WARN MemoryStore: Not enough space to cache rdd_8732_0 in memory! (computed 29.2 MiB so far)
# 22/04/27 11:36:10 WARN BlockManager: Persisting block rdd_8732_0 to disk instead.
# 22/04/27 11:36:10 WARN MemoryStore: Not enough space to cache rdd_8732_1 in memory! (computed 29.2 MiB so far)
# 22/04/27 11:36:10 WARN BlockManager: Persisting block rdd_8732_1 to disk instead.
# 22/04/27 11:36:10 WARN MemoryStore: Not enough space to cache rdd_8732_2 in memory! (computed 29.2 MiB so far)
# 22/04/27 11:36:10 WARN BlockManager: Persisting block rdd_8732_2 to disk instead.
# 22/04/27 11:36:11 WARN MemoryStore: Not enough space to cache rdd_8732_3 in memory! (computed 233.9 MiB so far)
# 22/04/27 11:36:15 WARN MemoryStore: Not enough space to cache rdd_8732_1 in memory! (computed 103.7 MiB so far)
# 22/04/27 11:36:15 WARN MemoryStore: Not enough space to cache rdd_8732_0 in memory! (computed 155.9 MiB so far)
# 22/04/27 11:36:15 WARN MemoryStore: Not enough space to cache rdd_8732_2 in memory! (computed 355.2 MiB so far)
# 22/04/27 11:36:17 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 22/04/27 11:36:18 WARN MemoryStore: Not enough space to cache rdd_8732_2 in memory! (computed 103.7 MiB so far)
# 22/04/27 11:36:18 WARN MemoryStore: Not enough space to cache rdd_8732_3 in memory! (computed 103.7 MiB so far)
# 22/04/27 11:36:18 WARN MemoryStore: Not enough space to cache rdd_8732_1 in memory! (computed 103.7 MiB so far)
# 22/04/27 11:36:18 WARN MemoryStore: Not enough space to cache rdd_8732_0 in memory! (computed 103.7 MiB so far)
# 22/04/27 11:36:20 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 22/04/27 11:36:20 WARN MemoryStore: Not enough space to cache rdd_8732_0 in memory! (computed 103.7 MiB so far)
# 22/04/27 11:36:20 WARN MemoryStore: Not enough space to cache rdd_8732_2 in memory! (computed 103.7 MiB so far)
# 22/04/27 11:36:20 WARN MemoryStore: Not enough space to cache rdd_8732_3 in memory! (computed 103.7 MiB so far)
# 22/04/27 11:36:20 WARN MemoryStore: Not enough space to cache rdd_8732_1 in memory! (computed 103.7 MiB so far)
# 22/04/27 11:36:23 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 22/04/27 11:36:23 WARN MemoryStore: Not enough space to cache rdd_8732_1 in memory! (computed 103.7 MiB so far)
# 22/04/27 11:36:23 WARN MemoryStore: Not enough space to cache rdd_8732_0 in memory! (computed 103.7 MiB so far)
# 22/04/27 11:36:23 WARN MemoryStore: Not enough space to cache rdd_8732_3 in memory! (computed 103.7 MiB so far)
# 22/04/27 11:36:23 WARN MemoryStore: Not enough space to cache rdd_8732_2 in memory! (computed 103.7 MiB so far)
# 22/04/27 11:36:25 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 22/04/27 11:36:26 WARN MemoryStore: Not enough space to cache rdd_8732_2 in memory! (computed 103.7 MiB so far)
# 22/04/27 11:36:26 WARN MemoryStore: Not enough space to cache rdd_8732_0 in memory! (computed 103.7 MiB so far)
# 22/04/27 11:36:26 WARN MemoryStore: Not enough space to cache rdd_8732_3 in memory! (computed 103.7 MiB so far)
# 22/04/27 11:36:26 WARN MemoryStore: Not enough space to cache rdd_8732_1 in memory! (computed 103.7 MiB so far)
# 22/04/27 11:36:28 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 22/04/27 11:36:29 WARN MemoryStore: Not enough space to cache rdd_8732_2 in memory! (computed 103.7 MiB so far)
# 22/04/27 11:36:29 WARN MemoryStore: Not enough space to cache rdd_8732_0 in memory! (computed 103.7 MiB so far)
# 22/04/27 11:36:29 WARN MemoryStore: Not enough space to cache rdd_8732_1 in memory! (computed 103.7 MiB so far)
# 22/04/27 11:36:29 WARN MemoryStore: Not enough space to cache rdd_8732_3 in memory! (computed 103.7 MiB so far)
# 22/04/27 11:36:31 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 22/04/27 11:36:32 WARN MemoryStore: Not enough space to cache rdd_8732_0 in memory! (computed 103.7 MiB so far)
# 22/04/27 11:36:32 WARN MemoryStore: Not enough space to cache rdd_8732_2 in memory! (computed 103.7 MiB so far)
# 22/04/27 11:36:32 WARN MemoryStore: Not enough space to cache rdd_8732_3 in memory! (computed 103.7 MiB so far)
# 22/04/27 11:36:32 WARN MemoryStore: Not enough space to cache rdd_8732_1 in memory! (computed 103.7 MiB so far)

# %%
test_metric = evaluator.evaluate(cvModel.transform(testData))
# Out:
# 22/04/27 11:37:25 WARN DAGScheduler: Broadcasting large task binary with size 2.4 MiB

# %%
test_metric
# Out:
# 0.7981008444584603

# %% [markdown]
# ## Print the parameters from the best model selected

# %%
best_Model = cvModel.bestModel
for i in range(len(best_Model.stages)):
    print(best_Model.stages[i])
# Out:
# StringIndexerModel: uid=StringIndexer_722d5a54cc00, handleInvalid=error
# VectorIndexerModel: uid=VectorIndexer_fca0cf2b4740, numFeatures=8018, handleInvalid=error
# DecisionTreeClassificationModel: uid=DecisionTreeClassifier_69aa8a77b962, depth=7, numNodes=179, numClasses=2, numFeatures=8018

# %%
java_model = best_Model.stages[-1]._java_obj
{param.name: java_model.getOrDefault(java_model.getParam(param.name)) 
    for param in grid[0]}
# Out:
# {'impurity': 'gini', 'maxBins': 5, 'minInfoGain': 0.0, 'maxDepth': 7}

# %%
predictionAndLabels = best_Model.transform(testData)

# %% [markdown]
# ## Calculate and print the Area under ROC Curve and Area under Precision-Recall Curve scores

# %%
metrics = BinaryClassificationMetrics(predictionAndLabels.select("prediction","indexedLabel").rdd)


print("Area under PR = %s" % metrics.areaUnderPR)


print("Area under ROC = %s" % metrics.areaUnderROC)
# Out:
# 22/04/27 11:50:09 WARN DAGScheduler: Broadcasting large task binary with size 2.4 MiB
# 22/04/27 11:50:11 WARN DAGScheduler: Broadcasting large task binary with size 2.4 MiB
# [Stage 1994:==============>                                         (1 + 3) / 4]
# Area under PR = 0.4831531580955708
# Area under ROC = 0.6112066519249517
